# %% [markdown]
# ## Setting up Panda

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\admin\\IronJulia\\IronJulia\\Labs\\9 Panda Case Study'

# %% [markdown]
# ## Reading Data

# %%
# the data is a new .csv files. It contains more columns than the two concetinated files from the Lab before. How to concetinate dataframes with different columns, see here: https://pythonexamples.org/pandas-concatenate-dataframes/ 
# Nevertheless, I decided to conduct all the previous tasks on this new dataset. 

df= pd.read_csv("Data_Marketing_Customer_Analysis_Round2.csv")
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# getting info about the new data frame. 

# i.e. I see that there are floating data type, integers and objects (i.e. strings)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
# the data frame exists of 10910 rows and 26 columns 

df.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## Standardizing data: Renaming Columns

# %%
# list current column names

df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
column_names = df.columns
column_names_clean = [column.lower().replace(" ", "_") for column in column_names]
df.columns = column_names_clean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10279 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %% [markdown]
# ## Deleting Columns

# %%
# delete the column "customer" as it is only a unique identifier for each row of data

df = df.drop(["customer"], axis =1) 

# axis=1 means column wise

# %%
# delete the column "unnamed:_0"

df = df.drop(["unnamed:_0"], axis =1) 

# axis=1 means column wise

# %%
df.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0     Arizona              4809.216960       No     Basic   College
# 1  California              2228.525238       No     Basic   College
# 2  Washington             14947.917300       No     Basic  Bachelor
# 3      Oregon             22332.439460      Yes  Extended   College
# 4      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  ...  \
# 0           2/18/11         Employed      M   48029      Suburban  ...
# 1           1/18/11       Unemployed      F       0      Suburban  ...
# 2           2/10/11         Employed      M   22139      Suburban  ...
# 3           1/11/11         Employed      M   49078      Suburban  ...
# 4           1/17/11    Medical Leave      F   23675      Suburban  ...
#
#   number_of_open_complaints  number_of_policies     policy_type        policy  \
# ...

# %% [markdown]
# ## Rearranging Columns

# %%
df.columns
# Out:
# Index(['state', 'customer_lifetime_value', 'response', 'coverage', 'education',
#        'effective_to_date', 'employmentstatus', 'gender', 'income',
#        'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
# rearraning columns in order the data to be more comprehensiv 

df = df[['state','gender','customer_lifetime_value','number_of_open_complaints','response', 'coverage', 'education',
       'effective_to_date', 'employmentstatus', 'income',
       'location_code', 'marital_status', 'monthly_premium_auto',
       'months_since_last_claim', 'months_since_policy_inception',
       'number_of_policies', 'policy_type',
       'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
       'vehicle_class', 'vehicle_size', 'vehicle_type']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          10279 non-null  object
#  1   gender                         10910 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   number_of_open_complaints      10277 non-null  float64
#  4   response                       10279 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %% [markdown]
# ## Correcting Data Types in Columns

# %%
# Check the data types of all the columns and fix the incorrect ones 
# The main method to convert a column to another data type is: astype()
# df["Customer Lifetime Value"].astype(float)
# (in previous Lab it was for customer lifetime value and number of complaints )

df.dtypes
# Out:
# state                             object
# gender                            object
# customer_lifetime_value          float64
# number_of_open_complaints        float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# vehicle_size                      object
# ...

# %%
# default is already float in the Data_Marketing_Customer_Analysis_Round2 file. No need to change in this file. 

df.customer_lifetime_value.dtype
# Out:
# dtype('float64')

# %%
# default is already float in the Data_Marketing_Customer_Analysis_Round2 file. No need to change in this file. 

df.number_of_open_complaints.dtype
# Out:
# dtype('float64')

# %%
# example for data type change in Data_Marketing_Customer_Analysis_Round2 file:
# "income" default it integer. change integer to float

df["income"].astype(float)
# Out:
# 0        48029.0
# 1            0.0
# 2        22139.0
# 3        49078.0
# 4        23675.0
#           ...
# 10905        0.0
# 10906    61146.0
# 10907    39837.0
# 10908    64195.0
# 10909        0.0
# Name: income, Length: 10910, dtype: float64

# %%
df.income = df["income"].astype(float)

# %%
df.income.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Filtering Data

# %%
# filtering data and correcting typos
# Filter the data in state and gender column to standardize the texts in those columns

# %%
df.gender.value_counts(dropna=False)

# No need to correct typos in gender in the file Data_Marketing_Customer_Analysis_Round2. All indices already assigned to F or M
# Out:
# F    5573
# M    5337
# Name: gender, dtype: int64

# %% [markdown]
# FYI How correction of gender worked in previous Lab:
#
# def gender_cl(x):
#
#     if not x == x:
#         return "n"
#
#     else:
#         dct_ = {"Male": "M",
#            "female": "F" ,
#            "Femal": "F" ,
#             "F": "F" ,
#             "M": "M"}
#
#         return dct_[x]
#
# gender_cl("Femal")
#
#
# df["gender"] = df["gender"].apply(gender_cl)
#
# df["gender"].value_counts()

# %%
# .value_counts() doesn't show the null values. dropna=False shows null values. 
# There are 631 rows that have no answer for "state"
# No need to correct typos in state in the file Data_Marketing_Customer_Analysis_Round2. All indices already assigned

df.state.value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
df["state"].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %% [markdown]
# FYI How filter & correction of state worked in previous Lab:
#
# def state_cl(x):
#
#     if not x==x:
#         # then I know, that x is NaN
#         return x
#     else:
#         dct_ = {'Washington': 'WA',
#                'Arizona':'AZ',
#                'Nevada': 'NV',
#                'California':'CA',
#                'Oregon':'OR',
#                'Cali':'CA',
#                'AZ':'AZ',
#                'WA':'WA'}
#
#         return dct_[x]
#
# state_cl("WA)
#
#
# df["state"] = df["state"].apply(state_cl)

# %%
# check for "education". 
# Data in file Data_Marketing_Customer_Analysis_Round2 is clean and has no typos (also checked for employmentstatus)

df.education.value_counts(dropna=False)
# Out:
# Bachelor                3272
# College                 3204
# High School or Below    3146
# Master                   887
# Doctor                   401
# Name: education, dtype: int64

# %% [markdown]
# ## Removing Duplicates

# %%
# drop duplicates across all columns 

df.drop_duplicates()

# drop duplicates across a subset of columns:
# df.drop_duplicates(subset=["gender", "state"])
# Out:
#             state gender  customer_lifetime_value  number_of_open_complaints  \
# 0         Arizona      M              4809.216960                        0.0
# 1      California      F              2228.525238                        0.0
# 2      Washington      M             14947.917300                        0.0
# 3          Oregon      M             22332.439460                        0.0
# 4          Oregon      F              9025.067525                        NaN
# ...           ...    ...                      ...                        ...
# 10905      Nevada      F             15563.369440                        NaN
# 10906      Oregon      F              5259.444853                        0.0
# 10907     Arizona      F             23893.304100                        0.0
# 10908  California      F             11971.977650                        4.0
# 10909         NaN      M              6857.519928                        0.0
#
# ...

# %% [markdown]
# ## Bucketing Data

# %%
# Replace column "State" to different zones. 
# California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# %%
def state_group(x):
    # checking for NaN. If x is NaN, return x
    if not x==x:
        return x
    
    else:

        dct_ = {"Washington":"east",
                "Arizona":"central",
                "Nevada": "central",
                "California":"west_region",
                "Oregon":"north_west",
               }
        
        return dct_[x]

df["region"] = df["state"].apply(state_group)

# %%
df[["region", "state"]]
# Out:
#             region       state
# 0          central     Arizona
# 1      west_region  California
# 2             east  Washington
# 3       north_west      Oregon
# 4       north_west      Oregon
# ...            ...         ...
# 10905      central      Nevada
# 10906   north_west      Oregon
# 10907      central     Arizona
# 10908  west_region  California
# 10909          NaN         NaN
#
# [10910 rows x 2 columns]

# %%
df["region"].unique()
# Out:
# array(['central', 'west_region', 'east', 'north_west', nan], dtype=object)

# %%
# Alternative for bucketing states to zones unsing map_function: 

df["region_mapped"] = list(map(state_group, df["state"]))

# %%
df[["region_mapped", "region", "state"]]
# Out:
#       region_mapped       region       state
# 0           central      central     Arizona
# 1       west_region  west_region  California
# 2              east         east  Washington
# 3        north_west   north_west      Oregon
# 4        north_west   north_west      Oregon
# ...             ...          ...         ...
# 10905       central      central      Nevada
# 10906    north_west   north_west      Oregon
# 10907       central      central     Arizona
# 10908   west_region  west_region  California
# 10909           NaN          NaN         NaN
#
# [10910 rows x 3 columns]

# %%
# drop empty region column

df=df.drop(columns="region")

# %%
df
# Out:
#             state gender  customer_lifetime_value  number_of_open_complaints  \
# 0         Arizona      M              4809.216960                        0.0
# 1      California      F              2228.525238                        0.0
# 2      Washington      M             14947.917300                        0.0
# 3          Oregon      M             22332.439460                        0.0
# 4          Oregon      F              9025.067525                        NaN
# ...           ...    ...                      ...                        ...
# 10905      Nevada      F             15563.369440                        NaN
# 10906      Oregon      F              5259.444853                        0.0
# 10907     Arizona      F             23893.304100                        0.0
# 10908  California      F             11971.977650                        4.0
# 10909         NaN      M              6857.519928                        0.0
#
# ...

# %% [markdown]
# ## Numerical Columns

# %%
# Check if the Index only consists of numeric data

# %%
import numpy as np

df_numerics_only = df.select_dtypes(include=np.number)
df_numerics_only

# in this dataframe there are 8 numerical columns

#Or 

# df.select_dtypes(include="number")
# Out:
#        customer_lifetime_value  number_of_open_complaints   income  \
# 0                  4809.216960                        0.0  48029.0
# 1                  2228.525238                        0.0      0.0
# 2                 14947.917300                        0.0  22139.0
# 3                 22332.439460                        0.0  49078.0
# 4                  9025.067525                        NaN  23675.0
# ...                        ...                        ...      ...
# 10905             15563.369440                        NaN      0.0
# 10906              5259.444853                        0.0  61146.0
# 10907             23893.304100                        0.0  39837.0
# 10908             11971.977650                        4.0  64195.0
# 10909              6857.519928                        0.0      0.0
#
#        monthly_premium_auto  months_since_last_claim  \
# 0                        61                      7.0
# ...

# %%
df.select_dtypes(exclude = ["object"])
# Out:
#        customer_lifetime_value  number_of_open_complaints   income  \
# 0                  4809.216960                        0.0  48029.0
# 1                  2228.525238                        0.0      0.0
# 2                 14947.917300                        0.0  22139.0
# 3                 22332.439460                        0.0  49078.0
# 4                  9025.067525                        NaN  23675.0
# ...                        ...                        ...      ...
# 10905             15563.369440                        NaN      0.0
# 10906              5259.444853                        0.0  61146.0
# 10907             23893.304100                        0.0  39837.0
# 10908             11971.977650                        4.0  64195.0
# 10909              6857.519928                        0.0      0.0
#
#        monthly_premium_auto  months_since_last_claim  \
# 0                        61                      7.0
# ...

# %%
df.select_dtypes("number").columns
# Out:
# Index(['customer_lifetime_value', 'number_of_open_complaints', 'income',
#        'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# ## Categorical Colums

# %%
# identify categorical columns 
# it is possible to change strings to categories in order to sort

# %%
df.select_dtypes("category").columns
# Out:
# Index([], dtype='object')

# %%
catCols = [col for col in df.columns if df[col].dtype=="O"]
catCols
# Out:
# ['state',
#  'gender',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type',
#  'region_mapped']

# %% [markdown]
# ## NaN Values

# %%
# Check and deal with NaN values.
# Replacing null values – Replace missing values with means of the column (for numerical columns)).

# %%
df.fillna("0", inplace = True)
df
# Out:
#             state gender  customer_lifetime_value number_of_open_complaints  \
# 0         Arizona      M              4809.216960                       0.0
# 1      California      F              2228.525238                       0.0
# 2      Washington      M             14947.917300                       0.0
# 3          Oregon      M             22332.439460                       0.0
# 4          Oregon      F              9025.067525                         0
# ...           ...    ...                      ...                       ...
# 10905      Nevada      F             15563.369440                         0
# 10906      Oregon      F              5259.444853                       0.0
# 10907     Arizona      F             23893.304100                       0.0
# 10908  California      F             11971.977650                       4.0
# 10909           0      M              6857.519928                       0.0
#
# ...

# %% [markdown]
# ## Datetime Format

# %%
# Extract the months from the dataset and store in a separate column. 
# Then filter the data to show only the information for the first quarter , ie. January, February and March. 
# Hint: If data from March does not exist, consider only January and February.

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html

# %%
# Saving file as .csv

df.to_csv("Lab_Customer_Analysis_Case_Study_Round2.csv")
