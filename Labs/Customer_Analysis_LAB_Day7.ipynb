# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Fredo\\Documents\\GitHub\\IronAlfred\\LAB CustomerAnalysis Day7'

# %%
df1 = pd.read_csv("file1.csv")
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv("file2.csv")
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
# Aggregating both data types
df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# standardizing header names
column_names = df.columns
column_names_clean = [column.lower().replace(" ", "_") for column in column_names]
df.columns = column_names_clean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5004 entries, 0 to 5003
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   2067 non-null   object
#  1   st                         2067 non-null   object
#  2   gender                     1945 non-null   object
#  3   education                  2067 non-null   object
#  4   customer_lifetime_value    2060 non-null   object
#  5   income                     2067 non-null   float64
#  6   monthly_premium_auto       2067 non-null   float64
#  7   number_of_open_complaints  2067 non-null   object
#  8   policy_type                2067 non-null   object
#  9   vehicle_class              2067 non-null   object
#  10  total_claim_amount         2067 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 430.2+ KB

# %%
# deleting columns:
df = df.drop(columns="customer")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5004 entries, 0 to 5003
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         2067 non-null   object
#  1   gender                     1945 non-null   object
#  2   education                  2067 non-null   object
#  3   customer_lifetime_value    2060 non-null   object
#  4   income                     2067 non-null   float64
#  5   monthly_premium_auto       2067 non-null   float64
#  6   number_of_open_complaints  2067 non-null   object
#  7   policy_type                2067 non-null   object
#  8   vehicle_class              2067 non-null   object
#  9   total_claim_amount         2067 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 391.1+ KB

# %%
#Rearranging columns:
df = df[["st", "gender", "education","customer_lifetime_value","number_of_open_complaints","policy_type","vehicle_class", "income","monthly_premium_auto", "total_claim_amount"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5004 entries, 0 to 5003
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   st                         2067 non-null   object
#  1   gender                     1945 non-null   object
#  2   education                  2067 non-null   object
#  3   customer_lifetime_value    2060 non-null   object
#  4   number_of_open_complaints  2067 non-null   object
#  5   policy_type                2067 non-null   object
#  6   vehicle_class              2067 non-null   object
#  7   income                     2067 non-null   float64
#  8   monthly_premium_auto       2067 non-null   float64
#  9   total_claim_amount         2067 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 391.1+ KB

# %%
# 
x=df["number_of_open_complaints"].value_counts()
# x.dtypes
# Out:
# 1/0/00    1626
# 1/1/00     247
# 1/2/00      93
# 1/3/00      60
# 1/4/00      29
# 1/5/00      12
# Name: number_of_open_complaints, dtype: int64

# %%
df["income"].value_counts()
# Out:
# 0.0        473
# 43860.0      5
# 36088.0      5
# 95697.0      5
# 20993.0      4
#           ...
# 37038.0      1
# 45768.0      1
# 72330.0      1
# 78435.0      1
# 42983.0      1
# Name: income, Length: 1455, dtype: int64

# %%
# turn "Customer lifetime Value" Column into a float by taking the the last lette % out

#x = value in the columns

def funct1(x):
# here we make sure it is a string
    x = str(x)
    
    if x != "nan":
# here we are selecting all the values of the string except for the last one -> which is the one we want to get rid of i.e. %
        y = x[: -1]
        return float(y)
    else:
        return 0

# here we are applyting the above defined function on any value in the customer_lifetime_value. First we are copying the df to the df2
df2 = df.copy()
df2["customer_lifetime_value"] = df2 ["customer_lifetime_value"].apply(funct1)

# %%
print(df2["customer_lifetime_value"].value_counts())
# Out:
# 0.00          2944
# 552821.28        5
# 251459.20        5
# 477294.38        4
# 650339.70        4
#               ...
# 3594471.05       1
# 513785.21        1
# 216387.02        1
# 2839332.99       1
# 1514793.06       1
# Name: customer_lifetime_value, Length: 1924, dtype: int64

# %%
# turn "number_of_open_complaints" Column into a float -> by selecting the 3 letter of the value only
def funct2(x):
    
    x = str(x)
    
    if x.lower() == "nan":
        return 0
    else:
# here we are selecting only the 3 value of the string -> seems to be the only one showing the amount of open complaints
        return (int(x[2]))


# again we are creating a new data frame and copy the df2 as the begining
df3 = df2.copy()
df3["number_of_open_complaints"] = df3 ["number_of_open_complaints"].apply(funct2)

# %%
print(df3["number_of_open_complaints"].value_counts())
# Out:
# 0    4563
# 1     247
# 2      93
# 3      60
# 4      29
# 5      12
# Name: number_of_open_complaints, dtype: int64

# %%
# - Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns

df.drop_duplicates

print(df3["st"].value_counts())
# Out:
# Oregon        623
# California    488
# Arizona       328
# Nevada        223
# Washington    181
# Cali          120
# AZ             74
# WA             30
# Name: st, dtype: int64

# %%
print(df3["gender"].value_counts())
# Out:
# F         984
# M         874
# Male       40
# female     30
# Femal      17
# Name: gender, dtype: int64

# %%
#filtering data

filter_state_AZ = df3["st"] == "AZ"
df3[filter_state_AZ]
# Out:
#       st gender             education  customer_lifetime_value  \
# 28    AZ    NaN               College               1290256.01
# 67    AZ    NaN  High School or Below               1163866.93
# 96    AZ    NaN                Master                837535.39
# 98    AZ    NaN              Bachelor                574594.33
# 112   AZ    NaN               College                849269.88
# ...   ..    ...                   ...                      ...
# 4866  AZ      M  High School or Below                244462.11
# 4871  AZ      F              Bachelor                722712.04
# 4874  AZ      F  High School or Below                428106.22
# 4880  AZ      M  High School or Below                734932.85
# 4886  AZ      F              Bachelor               1047989.97
#
#       number_of_open_complaints     policy_type  vehicle_class   income  \
# 28                            2   Personal Auto  Four-Door Car  86584.0
# ...

# %%
# turn the name of states 
# to change values in a column, write a function. There is always one value goes in and an other value goes out.

""""
here we do it the old way, only possible with little values to take care of

def state_cl1(x):
    if x == "Cali":
        return "California"
    elif x == "AZ":
        return "Arizona"
    else x == "WA":
        return "Washington"
"""""

# always try to come up with smart libaries/packages


def state_cl(x):


# why can you do it in the below way to check for none value, coz they have the wierd value that when you equal none values, it results a false
# then i know that x is NaN
    if not x == x:
        return x

# here I do the filtering/overwritting
    else:
        dct_ = {"Washington": "WA",
           "Arizona": "AZ" ,
           "Nevada": "NV" ,
           "California": "CA" ,
            "Oregon": "OR",
           "Cali" : "CA",
           "AZ": "AZ",
           "WA" : "WA"}
    
        return dct_[x]

state_cl("Oregon")
# Out:
# 'OR'

# %%
np.NaN == NaN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-70378da5bf43> in <module>
# ----> 1 NaN == NaN
#
# NameError: name 'NaN' is not defined

# %%
df3["st"].apply(state_cl)
# Out:
# 0       WA
# 1       AZ
# 2       NV
# 3       CA
# 4       WA
#         ..
# 4999    AZ
# 5000    AZ
# 5001    NV
# 5002    CA
# 5003    CA
# Name: st, Length: 5004, dtype: object

# %%
# IMPORTANT in order to alter the column in the old data frame we need to do the following
# we need to overright our old output with our created function!!

df3["st"] = df["st"].apply(state_cl)

# %%
df3
# Out:
#       st gender             education  customer_lifetime_value  \
# 0     WA    NaN                Master                     0.00
# 1     AZ      F              Bachelor                697953.59
# 2     NV      F              Bachelor               1288743.17
# 3     CA      M              Bachelor                764586.18
# 4     WA      M  High School or Below                536307.65
# ...   ..    ...                   ...                      ...
# 4999  AZ      M                Master                847141.75
# 5000  AZ      F               College                543121.91
# 5001  NV      F               College                568964.41
# 5002  CA      F                Master                368672.38
# 5003  CA      M              Bachelor                399258.39
#
#       number_of_open_complaints     policy_type  vehicle_class   income  \
# 0                             0   Personal Auto  Four-Door Car      0.0
# ...

# %%
df3["st"].unique()
# Out:
# array(['WA', 'AZ', 'NV', 'CA', 'OR', nan], dtype=object)

# %%
sum ((df3["gender"] == "Femal") | (df3["gender"] == "Male") | (df3["gender"] == "female"))
# Out:
# 87

# %%
df3["gender"].apply()

# %%
# standardizing the Gender Column by changing its values to corrects abbrivations

def gender_cl(x):


# why can you do it in the below way to check for none value, coz they have the wierd value that when you equal none values, it results a false
# then i know that x is NaN
    if not x == x:
        return "n"

# here I do the filtering/overwritting
    else:
        dct_ = {"Male": "M",
           "female": "F" ,
           "Femal": "F" ,
            "F": "F" ,
            "M": "M"}
    
        return dct_[x]

gender_cl("Femal")
# Out:
# 'F'

# %%
df3["gender"] = df["gender"].apply(gender_cl)

# %%
df3["gender"].value_counts()
# Out:
# n    3059
# F    1031
# M     914
# Name: gender, dtype: int64

# %%
# Removing duplicates

df3.drop_duplicates()

# QUESTION: how to readjust the amount of raws as well after duplication removal?
# df3.drop_duplicates(), ignore_index = "True"
# Out:
#       st gender             education  customer_lifetime_value  \
# 0     WA      n                Master                     0.00
# 1     AZ      F              Bachelor                697953.59
# 2     NV      F              Bachelor               1288743.17
# 3     CA      M              Bachelor                764586.18
# 4     WA      M  High School or Below                536307.65
# ...   ..    ...                   ...                      ...
# 4999  AZ      M                Master                847141.75
# 5000  AZ      F               College                543121.91
# 5001  NV      F               College                568964.41
# 5002  CA      F                Master                368672.38
# 5003  CA      M              Bachelor                399258.39
#
#       number_of_open_complaints     policy_type  vehicle_class   income  \
# 0                             0   Personal Auto  Four-Door Car      0.0
# ...

# %%
# Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# creating a new column

df3["Region"] = [" "]*df3.shape[0]
df3.head()
# Out:
#    st gender             education  customer_lifetime_value  \
# 0  WA      n                Master                     0.00
# 1  AZ      F              Bachelor                697953.59
# 2  NV      F              Bachelor               1288743.17
# 3  CA      M              Bachelor                764586.18
# 4  WA      M  High School or Below                536307.65
#
#    number_of_open_complaints     policy_type  vehicle_class   income  \
# 0                          0   Personal Auto  Four-Door Car      0.0
# 1                          0   Personal Auto  Four-Door Car      0.0
# 2                          0   Personal Auto   Two-Door Car  48767.0
# 3                          0  Corporate Auto            SUV      0.0
# 4                          0   Personal Auto  Four-Door Car  36357.0
#
#    monthly_premium_auto  total_claim_amount Region
# 0                1000.0            2.704934
# 1                  94.0         1131.464935
# 2                 108.0          566.472247
# ...

# %%
# mapping the St abbreviations to the new column called region

def region(x):
    
    if x !=x:
        return x

    else:
        dct_ = {"CA": "West Region",
           "WA": "East" ,
           "OR": "North West" ,
            "AZ": "Central" ,
            "NV": "Central"}
    
        return dct_[x]
    
region("CA")
# Out:
# 'West Region'

# %%
df3["region"] = df3["st"].apply(region)

# %%
df3
# Out:
#       st gender             education  customer_lifetime_value  \
# 0     WA      n                Master                     0.00
# 1     AZ      F              Bachelor                697953.59
# 2     NV      F              Bachelor               1288743.17
# 3     CA      M              Bachelor                764586.18
# 4     WA      M  High School or Below                536307.65
# ...   ..    ...                   ...                      ...
# 4999  AZ      M                Master                847141.75
# 5000  AZ      F               College                543121.91
# 5001  NV      F               College                568964.41
# 5002  CA      F                Master                368672.38
# 5003  CA      M              Bachelor                399258.39
#
#       number_of_open_complaints     policy_type  vehicle_class   income  \
# 0                             0   Personal Auto  Four-Door Car      0.0
# ...

# %%
#drop empty Region column
df4=df3.drop(columns="Region")

# %%
df4
# Out:
#       st gender             education  customer_lifetime_value  \
# 0     WA      n                Master                     0.00
# 1     AZ      F              Bachelor                697953.59
# 2     NV      F              Bachelor               1288743.17
# 3     CA      M              Bachelor                764586.18
# 4     WA      M  High School or Below                536307.65
# ...   ..    ...                   ...                      ...
# 4999  AZ      M                Master                847141.75
# 5000  AZ      F               College                543121.91
# 5001  NV      F               College                568964.41
# 5002  CA      F                Master                368672.38
# 5003  CA      M              Bachelor                399258.39
#
#       number_of_open_complaints     policy_type  vehicle_class   income  \
# 0                             0   Personal Auto  Four-Door Car      0.0
# ...
