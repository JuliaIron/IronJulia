# %% [markdown]
# # My Holiday Preferences

# %% [markdown]
# The purpose of this noteboot is to describe my holiday preferences with you

# %%
first_name = input("Enter your first name: ")
print (first_name)
# Out:
# Enter your first name: Julia
# Julia

# %% [markdown]
# ## Image of the traveller
# ![portrait.jpg](attachment:portrait.jpg)

# %%
holiday_preference = input ("Enter what kind of holiday activities you like: ")
# Out:
# Enter what kind of holiday activities you like: being active. I like to hike

# %%
holiday_preference = input ("Enter what climate you prefere: ")
# Out:
# Enter what climate you prefere: warm climate and countries

# %%
holiday_preference = input ("Enter if you prefere to travel with some one ore prefere to travel alone:")
# Out:
# Enter if you prefere to travel with some one ore prefere to travel alone:I usually travel on my own

# %% [markdown]
# ## The Destination: The Amazon Rainforest
# Amazon Rainforest in Brasil, in Acre state, close to the peruvian border

# %% [markdown]
# ![DJI_0766.jpg](attachment:DJI_0766.jpg)

# %% [markdown]
# ### Top 3 activities
# - <font color='green'>*hiking in the forest*</font>
# - <font color='green'>*listening to the stories of the indigenous people*</font>
# - <font color='green'>*singing and dancing with the indigenous people*</font>

# %% [markdown]
# There are projects that aims to prevent deforestation. Learn more about Acre Amazonian Rainforest Conservation:
# https://www.youtube.com/watch?v=Cca7FXh0TjM

# %% [markdown]
# **Annotations about this jupyter notebook**
#
# In this notebook we displayed the holiday preference of Julia:
# - by asking her to answer 3 questions and give input
